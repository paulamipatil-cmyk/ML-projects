# %%
# Download their historical performance

from pandas_datareader import data as web
import matplotlib.pyplot as plt
import yfinance as yf
import pandas
import numpy as np
import math

yf.pdr_override()

tickers = ["SGENX","SPY","FAGAX", "STAEX", "BIAGX", "ESEAX", "TGVFX", "MIGFX", "^SP500TR"]

multpl_index = web.get_data_yahoo(tickers, start='2022-07-21')

display(multpl_index)
# Out:
# [*********************100%***********************]  9 of 9 completed
#             Adj Close                                               \
#                 BIAGX      ESEAX       FAGAX      MIGFX      SGENX
# Date
# 2022-07-21  23.586597  26.421932   99.269997  34.294781  56.104343
# 2022-07-22  23.149118  26.205900   96.809998  33.959312  56.017895
# 2022-07-25  23.018805  26.168329   96.809998  33.892216  56.152370
# 2022-07-26  22.590635  25.961687   94.820000  33.575912  55.845001
# 2022-07-27  23.325970  26.393755   98.739998  34.524822  56.757504
# ...               ...        ...         ...        ...        ...
# 2023-07-20  26.440001  29.930000  118.989998  38.869999  64.339996
# 2023-07-21  26.480000  30.030001  118.699997  38.939999  64.349998
# 2023-07-24  26.440001  30.129999  118.730003  39.049999  64.360001
# 2023-07-25  26.600000  30.270000  119.589996  39.290001  64.589996
# 2023-07-26        NaN        NaN         NaN        NaN        NaN
#
# ...

# %%
#Calculate their historical volatilities
# Daily returns

SGENX = web.get_data_yahoo("SGENX", start='2022-07-21')

display(SGENX)

print("SGENX_daily_returns: ",SGENX['Adj Close'][1]/SGENX['Adj Close'][0]-1)
print("SGENX Logarithmic return: ",math.log(SGENX['Adj Close'][1]/SGENX['Adj Close'][0]))

SGENX_daily_returns = SGENX['Adj Close'].pct_change()
display(SGENX_daily_returns)


SPY = web.get_data_yahoo("SPY", start='2022-07-21')
display(SPY)

print("SPY Simple return:      ",SPY['Adj Close'][1]/SPY['Adj Close'][0]-1)
print("SPY Logarithmic return: ",math.log(SPY['Adj Close'][1]/SPY['Adj Close'][0]))

SPY_daily_returns = SPY['Adj Close'].pct_change()
display(SPY_daily_returns)


FAGAX = web.get_data_yahoo("FAGAX", start='2022-07-21')
display(FAGAX)

print("FAGAX Simple return:      ",FAGAX['Adj Close'][1]/FAGAX['Adj Close'][0]-1)
print("FAGAX Logarithmic return: ",math.log(FAGAX['Adj Close'][1]/FAGAX['Adj Close'][0]))

FAGAX_daily_returns = FAGAX['Adj Close'].pct_change()
display(FAGAX_daily_returns)



STAEX = web.get_data_yahoo("STAEX", start='2022-07-21')
display(STAEX)

print("STAEX Simple return:      ",STAEX['Adj Close'][1]/STAEX['Adj Close'][0]-1)
print("STAEX Logarithmic return: ",math.log(STAEX['Adj Close'][1]/STAEX['Adj Close'][0]))

STAEX_daily_returns = STAEX['Adj Close'].pct_change()
display(STAEX_daily_returns)


BIAGX = web.get_data_yahoo("BIAGX", start='2022-07-21')
display(BIAGX)

print("BIAGX Simple return:      ",BIAGX['Adj Close'][1]/BIAGX['Adj Close'][0]-1)
print("BIAGX Logarithmic return: ",math.log(BIAGX['Adj Close'][1]/BIAGX['Adj Close'][0]))

BIAGX_daily_returns = BIAGX['Adj Close'].pct_change()
display(BIAGX_daily_returns)


ESEAX = web.get_data_yahoo("ESEAX", start='2022-07-21')
display(ESEAX)

print("ESEAX Simple return:      ",ESEAX['Adj Close'][1]/ESEAX['Adj Close'][0]-1)
print("ESEAX Logarithmic return: ",math.log(ESEAX['Adj Close'][1]/ESEAX['Adj Close'][0]))

ESEAX_daily_returns = ESEAX['Adj Close'].pct_change()
display(ESEAX_daily_returns)


TGVFX = web.get_data_yahoo("TGVFX", start='2022-07-21')
display(TGVFX)

print("TGVFX Simple return:      ",TGVFX['Adj Close'][1]/TGVFX['Adj Close'][0]-1)
print("TGVFX Logarithmic return: ",math.log(TGVFX['Adj Close'][1]/TGVFX['Adj Close'][0]))

TGVFX_daily_returns = TGVFX['Adj Close'].pct_change()
display(TGVFX_daily_returns)


MIGFX = web.get_data_yahoo("MIGFX", start='2022-07-21')
display(MIGFX)

print("MIGFX Simple return:      ",MIGFX['Adj Close'][1]/MIGFX['Adj Close'][0]-1)
print("MIGFX Logarithmic return: ",math.log(MIGFX['Adj Close'][1]/MIGFX['Adj Close'][0]))

MIGFX_daily_returns = MIGFX['Adj Close'].pct_change()
display(MIGFX_daily_returns)



SP500TR = web.get_data_yahoo("^SP500TR", start='2022-07-21')
display(SP500TR)

print("SP500TR Simple return:      ",SP500TR['Adj Close'][1]/SP500TR['Adj Close'][0]-1)
print("SP500TR Logarithmic return: ",math.log(SP500TR['Adj Close'][1]/SP500TR['Adj Close'][0]))

SP500TR_daily_returns = SP500TR['Adj Close'].pct_change()
display(SP500TR_daily_returns)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2022-07-21  58.410000  58.410000  58.410000  58.410000  56.104343       0
# 2022-07-22  58.320000  58.320000  58.320000  58.320000  56.017895       0
# 2022-07-25  58.459999  58.459999  58.459999  58.459999  56.152370       0
# 2022-07-26  58.139999  58.139999  58.139999  58.139999  55.845001       0
# 2022-07-27  59.090000  59.090000  59.090000  59.090000  56.757504       0
# ...               ...        ...        ...        ...        ...     ...
# 2023-07-19  64.699997  64.699997  64.699997  64.699997  64.699997       0
# 2023-07-20  64.339996  64.339996  64.339996  64.339996  64.339996       0
# 2023-07-21  64.349998  64.349998  64.349998  64.349998  64.349998       0
# 2023-07-24  64.360001  64.360001  64.360001  64.360001  64.360001       0
# 2023-07-25  64.589996  64.589996  64.589996  64.589996  64.589996       0
#
# ...

# %%
#Calculate their historical volatilities continued
# Calculating the mean, standard deviation and other stats
print("SGENX historical volatilities calculation")
# Cumulative returns
SGENX_cum_returns = (SGENX_daily_returns + 1).cumprod()

# Monthly returns
SGENX_monthly_returns = SGENX['Adj Close'].resample('M').ffill().pct_change()

print("Daily returns(arithmetic):     ", SGENX_daily_returns.mean())

print("Daily returns(geometric) :     ", pow(SGENX_cum_returns[-1],1/(SGENX_cum_returns.count()-1))-1)
print("Daily volatility:  ", SGENX_daily_returns.std())

SGENX_daily_returns_mean = SGENX_daily_returns.mean()
SGENX_daily_returns_std = (((SGENX_daily_returns-SGENX_daily_returns_mean)**2).sum()/\
                                   (SGENX_daily_returns.count()-1))**0.5
print("Calculated value:  ", SGENX_daily_returns_std)
print()

print("Monthly returns(arithmetic):   ", SGENX_monthly_returns.mean())
print("Monthly volatility:", SGENX_monthly_returns.std())
SGENX_monthly_returns_mean = SGENX_monthly_returns.mean()
SGENX_monthly_returns_std = math.sqrt(((SGENX_monthly_returns-SGENX_monthly_returns_mean)**2).sum()/\
                                     (SGENX_monthly_returns.count()-1))
print("Calculated value:  ", SGENX_monthly_returns_std)
print()

print("Annualized volatility (from daily data):  ",SGENX_daily_returns.std()*math.sqrt(252))
print("Annualized volatility (from monthly data):",SGENX_monthly_returns.std()*math.sqrt(12))

SGENX['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("SGENX Price data")
plt.show()

fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
SGENX_daily_returns.plot.hist(bins = 60)
ax1.set_xlabel("Daily returns %")
ax1.set_ylabel("Percent")
ax1.set_title("SGENX daily returns data")
plt.show()


print("SPY historical volatilities calculation")
# Cumulative returns
SPY_cum_returns = (SPY_daily_returns + 1).cumprod()

# Monthly returns
SPY_monthly_returns = SPY['Adj Close'].resample('M').ffill().pct_change()

print("Daily returns(arithmetic):     ", SPY_daily_returns.mean())

print("Daily returns(geometric) :     ", pow(SPY_cum_returns[-1],1/(SPY_cum_returns.count()-1))-1)
print("Daily volatility:  ", SPY_daily_returns.std())

SPY_daily_returns_mean = SPY_daily_returns.mean()
SPY_daily_returns_std = (((SPY_daily_returns-SPY_daily_returns_mean)**2).sum()/\
                                   (SPY_daily_returns.count()-1))**0.5
print("Calculated value:  ", SPY_daily_returns_std)
print()

print("Monthly returns(arithmetic):   ", SPY_monthly_returns.mean())
print("Monthly volatility:", SPY_monthly_returns.std())
SPY_monthly_returns_mean = SPY_monthly_returns.mean()
SPY_monthly_returns_std = math.sqrt(((SPY_monthly_returns-SPY_monthly_returns_mean)**2).sum()/\
                                     (SPY_monthly_returns.count()-1))
print("Calculated value:  ", SPY_monthly_returns_std)
print()

print("Annualized volatility (from daily data):  ",SPY_daily_returns.std()*math.sqrt(252))
print("Annualized volatility (from monthly data):",SPY_monthly_returns.std()*math.sqrt(12))

SPY['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("SPY Price data")
plt.show()

fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
SPY_daily_returns.plot.hist(bins = 60)
ax1.set_xlabel("Daily returns %")
ax1.set_ylabel("Percent")
ax1.set_title("SPY daily returns data")
plt.show()

print("FAGAX historical volatilities calculation")
# Cumulative returns
FAGAX_cum_returns = (FAGAX_daily_returns + 1).cumprod()

# Monthly returns
FAGAX_monthly_returns = FAGAX['Adj Close'].resample('M').ffill().pct_change()

print("Daily returns(arithmetic):     ", FAGAX_daily_returns.mean())

print("Daily returns(geometric) :     ", pow(FAGAX_cum_returns[-1],1/(FAGAX_cum_returns.count()-1))-1)
print("Daily volatility:  ", FAGAX_daily_returns.std())

FAGAX_daily_returns_mean = FAGAX_daily_returns.mean()
FAGAX_daily_returns_std = (((FAGAX_daily_returns-FAGAX_daily_returns_mean)**2).sum()/\
                                   (FAGAX_daily_returns.count()-1))**0.5
print("Calculated value:  ", FAGAX_daily_returns_std)
print()

print("Monthly returns(arithmetic):   ", FAGAX_monthly_returns.mean())
print("Monthly volatility:", FAGAX_monthly_returns.std())
FAGAX_monthly_returns_mean = FAGAX_monthly_returns.mean()
FAGAX_monthly_returns_std = math.sqrt(((FAGAX_monthly_returns-FAGAX_monthly_returns_mean)**2).sum()/\
                                     (FAGAX_monthly_returns.count()-1))
print("Calculated value:  ", FAGAX_monthly_returns_std)
print()

print("Annualized volatility (from daily data):  ",FAGAX_daily_returns.std()*math.sqrt(252))
print("Annualized volatility (from monthly data):",FAGAX_monthly_returns.std()*math.sqrt(12))

FAGAX['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("FAGAX Price data")
plt.show()

fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
FAGAX_daily_returns.plot.hist(bins = 60)
ax1.set_xlabel("Daily returns %")
ax1.set_ylabel("Percent")
ax1.set_title("FAGAX daily returns data")
plt.show()

print("STAEX historical volatilities calculation")
# Cumulative returns
STAEX_cum_returns = (STAEX_daily_returns + 1).cumprod()

# Monthly returns
STAEX_monthly_returns = STAEX['Adj Close'].resample('M').ffill().pct_change()

print("Daily returns(arithmetic):     ", STAEX_daily_returns.mean())

print("Daily returns(geometric) :     ", pow(STAEX_cum_returns[-1],1/(STAEX_cum_returns.count()-1))-1)
print("Daily volatility:  ", STAEX_daily_returns.std())

STAEX_daily_returns_mean = STAEX_daily_returns.mean()
STAEX_daily_returns_std = (((STAEX_daily_returns-STAEX_daily_returns_mean)**2).sum()/\
                                   (STAEX_daily_returns.count()-1))**0.5
print("Calculated value:  ", STAEX_daily_returns_std)
print()

print("Monthly returns(arithmetic):   ", STAEX_monthly_returns.mean())
print("Monthly volatility:", STAEX_monthly_returns.std())
STAEX_monthly_returns_mean = STAEX_monthly_returns.mean()
STAEX_monthly_returns_std = math.sqrt(((STAEX_monthly_returns-STAEX_monthly_returns_mean)**2).sum()/\
                                     (STAEX_monthly_returns.count()-1))
print("Calculated value:  ", STAEX_monthly_returns_std)
print()

print("Annualized volatility (from daily data):  ",STAEX_daily_returns.std()*math.sqrt(252))
print("Annualized volatility (from monthly data):",STAEX_monthly_returns.std()*math.sqrt(12))

STAEX['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("STAEX Price data")
plt.show()

fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
STAEX_daily_returns.plot.hist(bins = 60)
ax1.set_xlabel("Daily returns %")
ax1.set_ylabel("Percent")
ax1.set_title("STAEX daily returns data")
plt.show()

print("BIAGX historical volatilities calculation")
# Cumulative returns
BIAGX_cum_returns = (BIAGX_daily_returns + 1).cumprod()

# Monthly returns
BIAGX_monthly_returns = BIAGX['Adj Close'].resample('M').ffill().pct_change()

print("Daily returns(arithmetic):     ", BIAGX_daily_returns.mean())

print("Daily returns(geometric) :     ", pow(BIAGX_cum_returns[-1],1/(BIAGX_cum_returns.count()-1))-1)
print("Daily volatility:  ", BIAGX_daily_returns.std())

BIAGX_daily_returns_mean = BIAGX_daily_returns.mean()
BIAGX_daily_returns_std = (((BIAGX_daily_returns-BIAGX_daily_returns_mean)**2).sum()/\
                                   (BIAGX_daily_returns.count()-1))**0.5
print("Calculated value:  ", BIAGX_daily_returns_std)
print()

print("Monthly returns(arithmetic):   ", BIAGX_monthly_returns.mean())
print("Monthly volatility:", BIAGX_monthly_returns.std())
BIAGX_monthly_returns_mean = BIAGX_monthly_returns.mean()
BIAGX_monthly_returns_std = math.sqrt(((BIAGX_monthly_returns-BIAGX_monthly_returns_mean)**2).sum()/\
                                     (BIAGX_monthly_returns.count()-1))
print("Calculated value:  ", BIAGX_monthly_returns_std)
print()

print("Annualized volatility (from daily data):  ",BIAGX_daily_returns.std()*math.sqrt(252))
print("Annualized volatility (from monthly data):",BIAGX_monthly_returns.std()*math.sqrt(12))

BIAGX['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("BIAGX Price data")
plt.show()

fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
BIAGX_daily_returns.plot.hist(bins = 60)
ax1.set_xlabel("Daily returns %")
ax1.set_ylabel("Percent")
ax1.set_title("BIAGX daily returns data")
plt.show()

print("ESEAX historical volatilities calculation")
# Cumulative returns
ESEAX_cum_returns = (ESEAX_daily_returns + 1).cumprod()

# Monthly returns
ESEAX_monthly_returns = ESEAX['Adj Close'].resample('M').ffill().pct_change()

print("Daily returns(arithmetic):     ", ESEAX_daily_returns.mean())

print("Daily returns(geometric) :     ", pow(ESEAX_cum_returns[-1],1/(ESEAX_cum_returns.count()-1))-1)
print("Daily volatility:  ", ESEAX_daily_returns.std())

ESEAX_daily_returns_mean = ESEAX_daily_returns.mean()
ESEAX_daily_returns_std = (((ESEAX_daily_returns-ESEAX_daily_returns_mean)**2).sum()/\
                                   (ESEAX_daily_returns.count()-1))**0.5
print("Calculated value:  ", ESEAX_daily_returns_std)
print()

print("Monthly returns(arithmetic):   ", ESEAX_monthly_returns.mean())
print("Monthly volatility:", ESEAX_monthly_returns.std())
ESEAX_monthly_returns_mean = ESEAX_monthly_returns.mean()
ESEAX_monthly_returns_std = math.sqrt(((ESEAX_monthly_returns-ESEAX_monthly_returns_mean)**2).sum()/\
                                     (ESEAX_monthly_returns.count()-1))
print("Calculated value:  ", ESEAX_monthly_returns_std)
print()

print("Annualized volatility (from daily data):  ",ESEAX_daily_returns.std()*math.sqrt(252))
print("Annualized volatility (from monthly data):",ESEAX_monthly_returns.std()*math.sqrt(12))

ESEAX['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("ESEAX Price data")
plt.show()

fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ESEAX_daily_returns.plot.hist(bins = 60)
ax1.set_xlabel("Daily returns %")
ax1.set_ylabel("Percent")
ax1.set_title("ESEAX daily returns data")
plt.show()

print("TGVFX historical volatilities calculation")
# Cumulative returns
TGVFX_cum_returns = (TGVFX_daily_returns + 1).cumprod()

# Monthly returns
TGVFX_monthly_returns = TGVFX['Adj Close'].resample('M').ffill().pct_change()

print("Daily returns(arithmetic):     ", TGVFX_daily_returns.mean())

print("Daily returns(geometric) :     ", pow(TGVFX_cum_returns[-1],1/(TGVFX_cum_returns.count()-1))-1)
print("Daily volatility:  ", TGVFX_daily_returns.std())

TGVFX_daily_returns_mean = TGVFX_daily_returns.mean()
TGVFX_daily_returns_std = (((TGVFX_daily_returns-TGVFX_daily_returns_mean)**2).sum()/\
                                   (TGVFX_daily_returns.count()-1))**0.5
print("Calculated value:  ", TGVFX_daily_returns_std)
print()

print("Monthly returns(arithmetic):   ", TGVFX_monthly_returns.mean())
print("Monthly volatility:", TGVFX_monthly_returns.std())
TGVFX_monthly_returns_mean = TGVFX_monthly_returns.mean()
TGVFX_monthly_returns_std = math.sqrt(((TGVFX_monthly_returns-TGVFX_monthly_returns_mean)**2).sum()/\
                                     (TGVFX_monthly_returns.count()-1))
print("Calculated value:  ", TGVFX_monthly_returns_std)
print()

print("Annualized volatility (from daily data):  ",TGVFX_daily_returns.std()*math.sqrt(252))
print("Annualized volatility (from monthly data):",TGVFX_monthly_returns.std()*math.sqrt(12))

TGVFX['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("TGVFX Price data")
plt.show()

fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
TGVFX_daily_returns.plot.hist(bins = 60)
ax1.set_xlabel("Daily returns %")
ax1.set_ylabel("Percent")
ax1.set_title("TGVFX daily returns data")
plt.show()

print("MIGFX historical volatilities calculation")
# Cumulative returns
MIGFX_cum_returns = (MIGFX_daily_returns + 1).cumprod()

# Monthly returns
MIGFX_monthly_returns = MIGFX['Adj Close'].resample('M').ffill().pct_change()

print("Daily returns(arithmetic):     ", MIGFX_daily_returns.mean())

print("Daily returns(geometric) :     ", pow(MIGFX_cum_returns[-1],1/(MIGFX_cum_returns.count()-1))-1)
print("Daily volatility:  ", MIGFX_daily_returns.std())

MIGFX_daily_returns_mean = MIGFX_daily_returns.mean()
MIGFX_daily_returns_std = (((MIGFX_daily_returns-MIGFX_daily_returns_mean)**2).sum()/\
                                   (MIGFX_daily_returns.count()-1))**0.5
print("Calculated value:  ", MIGFX_daily_returns_std)
print()

print("Monthly returns(arithmetic):   ", MIGFX_monthly_returns.mean())
print("Monthly volatility:", MIGFX_monthly_returns.std())
MIGFX_monthly_returns_mean = MIGFX_monthly_returns.mean()
MIGFX_monthly_returns_std = math.sqrt(((MIGFX_monthly_returns-MIGFX_monthly_returns_mean)**2).sum()/\
                                     (MIGFX_monthly_returns.count()-1))
print("Calculated value:  ", MIGFX_monthly_returns_std)
print()

print("Annualized volatility (from daily data):  ",MIGFX_daily_returns.std()*math.sqrt(252))
print("Annualized volatility (from monthly data):",MIGFX_monthly_returns.std()*math.sqrt(12))

MIGFX['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("MIGFX Price data")
plt.show()

fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
MIGFX_daily_returns.plot.hist(bins = 60)
ax1.set_xlabel("Daily returns %")
ax1.set_ylabel("Percent")
ax1.set_title("MIGFX daily returns data")
plt.show()

print("SP500TR historical volatilities calculation")
# Cumulative returns
SP500TR_cum_returns = (SP500TR_daily_returns + 1).cumprod()

# Monthly returns
SP500TR_monthly_returns = SP500TR['Adj Close'].resample('M').ffill().pct_change()

print("Daily returns(arithmetic):     ", SP500TR_daily_returns.mean())

print("Daily returns(geometric) :     ", pow(SP500TR_cum_returns[-1],1/(SP500TR_cum_returns.count()-1))-1)
print("Daily volatility:  ", SP500TR_daily_returns.std())

SP500TR_daily_returns_mean = SP500TR_daily_returns.mean()
SP500TR_daily_returns_std = (((SP500TR_daily_returns-SP500TR_daily_returns_mean)**2).sum()/\
                                   (SP500TR_daily_returns.count()-1))**0.5
print("Calculated value:  ", SP500TR_daily_returns_std)
print()

print("Monthly returns(arithmetic):   ", SP500TR_monthly_returns.mean())
print("Monthly volatility:", SP500TR_monthly_returns.std())
SP500TR_monthly_returns_mean = SP500TR_monthly_returns.mean()
SP500TR_monthly_returns_std = math.sqrt(((SP500TR_monthly_returns-SP500TR_monthly_returns_mean)**2).sum()/\
                                     (SP500TR_monthly_returns.count()-1))
print("Calculated value:  ", SP500TR_monthly_returns_std)
print()

print("Annualized volatility (from daily data):  ",SP500TR_daily_returns.std()*math.sqrt(252))
print("Annualized volatility (from monthly data):",SP500TR_monthly_returns.std()*math.sqrt(12))

SP500TR['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("SP500TR Price data")
plt.show()

fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
SP500TR_daily_returns.plot.hist(bins = 60)
ax1.set_xlabel("Daily returns %")
ax1.set_ylabel("Percent")
ax1.set_title("SP500TR daily returns data")
plt.show()
# Out:
# SGENX historical volatilities calculation
# Daily returns(arithmetic):      0.0005933065664775228
# Daily returns(geometric) :      0.0005590701544322396
# Daily volatility:   0.008562840330321859
# Calculated value:   0.00856284033032186
#
# Monthly returns(arithmetic):    0.010727583436957983
# Monthly volatility: 0.0499875938053966
# Calculated value:   0.0499875938053966
#
# Annualized volatility (from daily data):   0.13593087618231486
# Annualized volatility (from monthly data): 0.17316210443812438
# SPY historical volatilities calculation
# Daily returns(arithmetic):      0.0006598994872011111
# Daily returns(geometric) :      0.0005915515633909685
# Daily volatility:   0.011927352538087362
# Calculated value:   0.011927352538087358
#
# Monthly returns(arithmetic):    0.011136356270590267
# Monthly volatility: 0.05471393881013967
# Calculated value:   0.05471393881013967
#
# Annualized volatility (from daily data):   0.18934085169104525
# ...

# %%
#Compare their performance
print("      Daily Percent Change of Adj Close of Stocks")
SP500_SGENX=multpl_index['Adj Close']['SGENX'].pct_change()
SP500_SPY=multpl_index['Adj Close']['SPY'].pct_change()
SP500_FAGAX=multpl_index['Adj Close']['FAGAX'].pct_change()
SP500_STAEX=multpl_index['Adj Close']['STAEX'].pct_change()
SP500_BIAGX=multpl_index['Adj Close']['BIAGX'].pct_change()
SP500_ESEAX=multpl_index['Adj Close']['ESEAX'].pct_change()
SP500_TGVFX=multpl_index['Adj Close']['TGVFX'].pct_change()
SP500_MIGFX=multpl_index['Adj Close']['MIGFX'].pct_change()
SP500TR=multpl_index['Adj Close']['^SP500TR'].pct_change()

# Merge Data Series
df={}
df['SGENX']=SP500_SGENX
df['SPY']=SP500_SPY
df['FAGAX']=SP500_FAGAX
df['STAEX']=SP500_STAEX
df['BIAGX']=SP500_BIAGX
df['ESEAX']=SP500_ESEAX
df['TGVFX']=SP500_TGVFX
df['MIGFX']=SP500_MIGFX
df['SPY']=SP500_SPY
df['SP500TR']=SP500TR
df=pandas.DataFrame(df)

display(df)

# Plot 

df.plot(figsize=(20, 8))
plt.show()

print("      Monthly Percent Change of Adj Close of Stocks")

multpl_stock_daily_returns = multpl_index['Adj Close'].pct_change()
multpl_stock_monthly_returns = multpl_index['Adj Close'].resample('M').ffill().pct_change()

#portfolio_monthly_returns = pandas.DataFrame((multpl_stock_monthly_returns).sum(axis = 1))
#portfolio_monthly_returns.columns=['Portfolio']

dat = pandas.concat([multpl_stock_monthly_returns], axis=1)
display(dat)

(dat + 1).cumprod().plot()
plt.show()
# Out:
#       Daily Percent Change of Adj Close of Stocks
#                SGENX       SPY     FAGAX     STAEX     BIAGX     ESEAX  \
# Date
# 2022-07-21       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-07-22 -0.001541 -0.009278 -0.024781 -0.020134 -0.018548 -0.008176
# 2022-07-25  0.002401  0.001215  0.000000 -0.004110 -0.005629 -0.001434
# 2022-07-26 -0.005474 -0.011831 -0.020556 -0.020633 -0.018601 -0.007897
# 2022-07-27  0.016340  0.025966  0.041341  0.039326  0.032550  0.016643
# ...              ...       ...       ...       ...       ...       ...
# 2023-07-20 -0.005564 -0.006634 -0.022429 -0.015979 -0.019288 -0.001335
# 2023-07-21  0.000155  0.000000 -0.002437  0.002706  0.001513  0.003341
# 2023-07-24  0.000155  0.004467  0.000253 -0.001349 -0.001511  0.003330
# 2023-07-25  0.003574  0.002730  0.007243  0.002703  0.006051  0.004647
# 2023-07-26  0.000000 -0.002108  0.000000  0.000000  0.000000  0.000000
#
#                TGVFX     MIGFX   SP500TR
# Date
# ...
